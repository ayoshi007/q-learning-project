# %%
import pandas as pd

# %%
log_metrics = pd.read_csv('model_metrics.csv')
log_histories = pd.read_excel('model_histories.xlsx',header = None,index_col = None,engine = 'openpyxl')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
line = sns.lineplot(data = log_histories[:1000].transpose(),legend=False)
line.set_xlabel("Iterations")
line.set_ylabel("Amount of Steps Taken")
line.set_title("Steps VS. Iterations")
line
# Out:
# <AxesSubplot:title={'center':'Steps VS. Iterations'}, xlabel='Iterations', ylabel='Amount of Steps Taken'>
